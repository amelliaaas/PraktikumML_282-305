# %% [markdown]
# <a href="https://colab.research.google.com/github/amelliaaas/PraktikumML_282-305/blob/Kelas_mechine_learning/ML_Project_Skenario_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/COVID-19_Radiography/dataset
# Out:
# /content/drive/MyDrive/COVID-19_Radiography/dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras

import os
import random
import cv2
from tqdm import tqdm

# %%
labels = ['Covid', 'Normal', 'Viral Pneumonia']
IMG_SIZE = 124

# %%
# load all the images
def loadData(DIR):
    X = []
    Y = []
    for label in labels:
        path = os.path.join(DIR, label)
        class_num = labels.index(label)
        for img in tqdm(os.listdir(path)):
            try:
                arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(arr, (IMG_SIZE, IMG_SIZE))
                X.append(resized_arr)
                Y.append(class_num)
            except Exception as e:
                print(e)
    return (np.array(X), np.array(Y))

# %%
DIR = '/content/drive/MyDrive/COVID-19_Radiography/dataset'
(X, Y) = loadData(DIR)
# Out:
# 100%|██████████| 219/219 [00:03<00:00, 63.04it/s]
# 100%|██████████| 1341/1341 [00:25<00:00, 52.23it/s]
# 100%|██████████| 1350/1350 [00:24<00:00, 55.85it/s]

# %% [markdown]
# ## Visualisasi Data

# %%
l = []
for img in Y:
    l.append(labels[img])
sns.countplot(l);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, ax = plt.subplots(3)
fig.set_size_inches(15, 20)
for i in range(3):
        l = random.randint(0, len(X))
        ax[i].imshow(X[l])
        ax[i].set_title('Image: ' + labels[Y[l]])

# %% [markdown]
# ## Preprocessing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# normalize the data
X = X / 255

# reshape the data
X = X.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y = Y.reshape(-1, 1)
Y = keras.utils.to_categorical(Y, 3)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# Explore the dataset
print("X_train shape:" + str(X_train.shape))
print("Y_train shape:" + str(Y_train.shape))
print("X_test shape:" + str(X_test.shape))
print("Y_test shape:" + str(Y_test.shape))
# Out:
# X_train shape:(2037, 124, 124, 3)
# Y_train shape:(2037, 3)
# X_test shape:(873, 124, 124, 3)
# Y_test shape:(873, 3)

# %% [markdown]
# ## CNN Model from scratch

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten,BatchNormalization
from keras.layers import Dense

# %%
model = Sequential(
    [
        Conv2D(filters = 32, kernel_size = (3, 3), padding = 'same', activation = 'relu', input_shape = (IMG_SIZE, IMG_SIZE, 3)),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        
        Conv2D(filters = 64, kernel_size = (3, 3), padding = 'same', activation = 'relu'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        
        Conv2D(filters = 128, kernel_size = (3, 3), padding = 'same', activation = 'relu'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        
        Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same', activation = 'relu'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        
        Conv2D(filters = 512, kernel_size = (3, 3), padding = 'same', activation = 'relu'),
        MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
     
        Flatten(),
        Dense(1024, activation = 'relu'),
        Dropout(0.5),
        Dense(3, activation = 'softmax')
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 62, 62, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 31, 31, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 512)         1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 1024)              4719616
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 3)                 3075
#
# =================================================================
# Total params: 6,291,267
# Trainable params: 6,291,267
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 51/51 [==============================] - 14s 77ms/step - loss: 0.8100 - accuracy: 0.6016 - val_loss: 0.4673 - val_accuracy: 0.8235
# Epoch 2/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.4550 - accuracy: 0.8244 - val_loss: 0.3163 - val_accuracy: 0.8995
# Epoch 3/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.2704 - accuracy: 0.8926 - val_loss: 0.2174 - val_accuracy: 0.9240
# Epoch 4/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.2245 - accuracy: 0.9208 - val_loss: 0.2117 - val_accuracy: 0.9142
# Epoch 5/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.2030 - accuracy: 0.9227 - val_loss: 0.2061 - val_accuracy: 0.9289
# Epoch 6/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.1439 - accuracy: 0.9472 - val_loss: 0.1695 - val_accuracy: 0.9363
# Epoch 7/100
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1132 - accuracy: 0.9626 - val_loss: 0.2014 - val_accuracy: 0.9314
# Epoch 8/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0822 - accuracy: 0.9742 - val_loss: 0.2079 - val_accuracy: 0.9436
# Epoch 9/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0767 - accuracy: 0.9748 - val_loss: 0.3148 - val_accuracy: 0.9265
# Epoch 10/100
# 51/51 [==============================] - 3s 53ms/step - loss: 0.0436 - accuracy: 0.9834 - val_loss: 0.2101 - val_accuracy: 0.9412
# Epoch 11/100
# 51/51 [==============================] - 3s 54ms/step - loss: 0.0517 - accuracy: 0.9797 - val_loss: 0.2878 - val_accuracy: 0.9363
# Epoch 12/100
# 51/51 [==============================] - 3s 53ms/step - loss: 0.0255 - accuracy: 0.9883 - val_loss: 0.2298 - val_accuracy: 0.9436
# Epoch 13/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0371 - accuracy: 0.9871 - val_loss: 0.2463 - val_accuracy: 0.9289
# Epoch 14/100
# 51/51 [==============================] - 3s 51ms/step - loss: 0.0278 - accuracy: 0.9877 - val_loss: 0.3043 - val_accuracy: 0.9412
# Epoch 15/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0304 - accuracy: 0.9883 - val_loss: 0.3405 - val_accuracy: 0.9363
# Epoch 16/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0648 - accuracy: 0.9834 - val_loss: 0.4733 - val_accuracy: 0.9020
# Epoch 17/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0318 - accuracy: 0.9908 - val_loss: 0.2834 - val_accuracy: 0.9412
# Epoch 18/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.2904 - val_accuracy: 0.9436
# Epoch 19/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3758 - val_accuracy: 0.9412
# Epoch 20/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.3505 - val_accuracy: 0.9510
# Epoch 21/100
# 51/51 [==============================] - 3s 54ms/step - loss: 2.5976e-04 - accuracy: 1.0000 - val_loss: 0.3608 - val_accuracy: 0.9485
# Epoch 22/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.1138e-04 - accuracy: 1.0000 - val_loss: 0.3735 - val_accuracy: 0.9412
# Epoch 23/100
# 51/51 [==============================] - 3s 54ms/step - loss: 7.4308e-05 - accuracy: 1.0000 - val_loss: 0.3888 - val_accuracy: 0.9412
# Epoch 24/100
# 51/51 [==============================] - 3s 52ms/step - loss: 7.7782e-05 - accuracy: 1.0000 - val_loss: 0.4120 - val_accuracy: 0.9387
# Epoch 25/100
# 51/51 [==============================] - 3s 51ms/step - loss: 3.2496e-05 - accuracy: 1.0000 - val_loss: 0.4178 - val_accuracy: 0.9412
# Epoch 26/100
# 51/51 [==============================] - 3s 52ms/step - loss: 5.0098e-05 - accuracy: 1.0000 - val_loss: 0.4325 - val_accuracy: 0.9461
# Epoch 27/100
# 51/51 [==============================] - 3s 52ms/step - loss: 3.3169e-05 - accuracy: 1.0000 - val_loss: 0.4325 - val_accuracy: 0.9485
# Epoch 28/100
# 51/51 [==============================] - 3s 52ms/step - loss: 7.8605e-05 - accuracy: 1.0000 - val_loss: 0.4226 - val_accuracy: 0.9461
# Epoch 29/100
# 51/51 [==============================] - 3s 52ms/step - loss: 3.9948e-05 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.9436
# Epoch 30/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.9476e-05 - accuracy: 1.0000 - val_loss: 0.4365 - val_accuracy: 0.9461
# Epoch 31/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.2321e-05 - accuracy: 1.0000 - val_loss: 0.4401 - val_accuracy: 0.9485
# Epoch 32/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.6826e-05 - accuracy: 1.0000 - val_loss: 0.4466 - val_accuracy: 0.9461
# Epoch 33/100
# 51/51 [==============================] - 3s 52ms/step - loss: 3.6450e-05 - accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.9387
# Epoch 34/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.5874e-05 - accuracy: 1.0000 - val_loss: 0.4575 - val_accuracy: 0.9412
# Epoch 35/100
# 51/51 [==============================] - 3s 54ms/step - loss: 1.7456e-05 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.9436
# Epoch 36/100
# 51/51 [==============================] - 3s 52ms/step - loss: 8.5848e-06 - accuracy: 1.0000 - val_loss: 0.4636 - val_accuracy: 0.9461
# Epoch 37/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.1936e-05 - accuracy: 1.0000 - val_loss: 0.4653 - val_accuracy: 0.9461
# Epoch 38/100
# 51/51 [==============================] - 3s 54ms/step - loss: 7.2124e-06 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.9461
# Epoch 39/100
# 51/51 [==============================] - 3s 51ms/step - loss: 8.4515e-06 - accuracy: 1.0000 - val_loss: 0.4723 - val_accuracy: 0.9461
# Epoch 40/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.3510e-05 - accuracy: 1.0000 - val_loss: 0.4757 - val_accuracy: 0.9412
# Epoch 41/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.1160e-05 - accuracy: 1.0000 - val_loss: 0.4789 - val_accuracy: 0.9412
# Epoch 42/100
# 51/51 [==============================] - 3s 52ms/step - loss: 8.8494e-06 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.9412
# Epoch 43/100
# 51/51 [==============================] - 3s 52ms/step - loss: 8.5745e-06 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.9387
# Epoch 44/100
# 51/51 [==============================] - 3s 52ms/step - loss: 6.5844e-06 - accuracy: 1.0000 - val_loss: 0.4863 - val_accuracy: 0.9412
# Epoch 45/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.3525e-05 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.9412
# Epoch 46/100
# 51/51 [==============================] - 3s 51ms/step - loss: 6.4027e-06 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.9412
# Epoch 47/100
# 51/51 [==============================] - 3s 51ms/step - loss: 1.1405e-05 - accuracy: 1.0000 - val_loss: 0.4982 - val_accuracy: 0.9412
# Epoch 48/100
# 51/51 [==============================] - 3s 51ms/step - loss: 1.0505e-05 - accuracy: 1.0000 - val_loss: 0.4965 - val_accuracy: 0.9412
# Epoch 49/100
# 51/51 [==============================] - 3s 51ms/step - loss: 4.8133e-06 - accuracy: 1.0000 - val_loss: 0.4971 - val_accuracy: 0.9412
# Epoch 50/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.2815e-06 - accuracy: 1.0000 - val_loss: 0.4989 - val_accuracy: 0.9461
# Epoch 51/100
# 51/51 [==============================] - 3s 52ms/step - loss: 3.7511e-06 - accuracy: 1.0000 - val_loss: 0.5007 - val_accuracy: 0.9412
# Epoch 52/100
# 51/51 [==============================] - 3s 51ms/step - loss: 3.9016e-06 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.9461
# Epoch 53/100
# 51/51 [==============================] - 3s 54ms/step - loss: 5.0721e-06 - accuracy: 1.0000 - val_loss: 0.5064 - val_accuracy: 0.9461
# Epoch 54/100
# 51/51 [==============================] - 3s 53ms/step - loss: 7.4052e-06 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.9436
# Epoch 55/100
# 51/51 [==============================] - 3s 52ms/step - loss: 8.1178e-06 - accuracy: 1.0000 - val_loss: 0.5063 - val_accuracy: 0.9436
# Epoch 56/100
# 51/51 [==============================] - 3s 52ms/step - loss: 5.3888e-06 - accuracy: 1.0000 - val_loss: 0.5084 - val_accuracy: 0.9436
# Epoch 57/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.7067e-05 - accuracy: 1.0000 - val_loss: 0.4898 - val_accuracy: 0.9510
# Epoch 58/100
# 51/51 [==============================] - 3s 51ms/step - loss: 1.2526e-05 - accuracy: 1.0000 - val_loss: 0.4949 - val_accuracy: 0.9412
# Epoch 59/100
# 51/51 [==============================] - 3s 55ms/step - loss: 3.7534e-06 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.9412
# Epoch 60/100
# 51/51 [==============================] - 3s 51ms/step - loss: 4.8924e-06 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 0.9412
# Epoch 61/100
# 51/51 [==============================] - 3s 51ms/step - loss: 3.8024e-06 - accuracy: 1.0000 - val_loss: 0.5169 - val_accuracy: 0.9461
# Epoch 62/100
# 51/51 [==============================] - 3s 54ms/step - loss: 2.3040e-06 - accuracy: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.9461
# Epoch 63/100
# 51/51 [==============================] - 3s 51ms/step - loss: 4.2280e-06 - accuracy: 1.0000 - val_loss: 0.5179 - val_accuracy: 0.9412
# Epoch 64/100
# 51/51 [==============================] - 3s 52ms/step - loss: 9.8574e-06 - accuracy: 1.0000 - val_loss: 0.5143 - val_accuracy: 0.9485
# Epoch 65/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.6438e-06 - accuracy: 1.0000 - val_loss: 0.5074 - val_accuracy: 0.9510
# Epoch 66/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.2850e-06 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.9510
# Epoch 67/100
# 51/51 [==============================] - 3s 52ms/step - loss: 4.3308e-06 - accuracy: 1.0000 - val_loss: 0.5106 - val_accuracy: 0.9461
# Epoch 68/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.9648e-06 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.9461
# Epoch 69/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.6128e-06 - accuracy: 1.0000 - val_loss: 0.5145 - val_accuracy: 0.9461
# Epoch 70/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.8034e-06 - accuracy: 1.0000 - val_loss: 0.5176 - val_accuracy: 0.9436
# Epoch 71/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.1906e-06 - accuracy: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.9461
# Epoch 72/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.7377e-06 - accuracy: 1.0000 - val_loss: 0.5212 - val_accuracy: 0.9436
# Epoch 73/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.9700e-06 - accuracy: 1.0000 - val_loss: 0.5234 - val_accuracy: 0.9436
# Epoch 74/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.0391e-06 - accuracy: 1.0000 - val_loss: 0.5259 - val_accuracy: 0.9461
# Epoch 75/100
# 51/51 [==============================] - 3s 54ms/step - loss: 1.7757e-06 - accuracy: 1.0000 - val_loss: 0.5291 - val_accuracy: 0.9461
# Epoch 76/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.4243e-06 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.9412
# Epoch 77/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.1174e-06 - accuracy: 1.0000 - val_loss: 0.5321 - val_accuracy: 0.9436
# Epoch 78/100
# 51/51 [==============================] - 3s 52ms/step - loss: 8.6335e-07 - accuracy: 1.0000 - val_loss: 0.5335 - val_accuracy: 0.9436
# Epoch 79/100
# 51/51 [==============================] - 3s 55ms/step - loss: 1.3301e-06 - accuracy: 1.0000 - val_loss: 0.5345 - val_accuracy: 0.9461
# Epoch 80/100
# 51/51 [==============================] - 3s 54ms/step - loss: 1.5970e-06 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.9461
# Epoch 81/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.6820e-06 - accuracy: 1.0000 - val_loss: 0.5366 - val_accuracy: 0.9412
# Epoch 82/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.6648e-06 - accuracy: 1.0000 - val_loss: 0.5399 - val_accuracy: 0.9412
# Epoch 83/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.0538e-06 - accuracy: 1.0000 - val_loss: 0.5420 - val_accuracy: 0.9412
# Epoch 84/100
# 51/51 [==============================] - 3s 54ms/step - loss: 8.5317e-07 - accuracy: 1.0000 - val_loss: 0.5440 - val_accuracy: 0.9412
# Epoch 85/100
# 51/51 [==============================] - 3s 53ms/step - loss: 3.0709e-06 - accuracy: 1.0000 - val_loss: 0.5498 - val_accuracy: 0.9461
# Epoch 86/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.7306e-06 - accuracy: 1.0000 - val_loss: 0.5500 - val_accuracy: 0.9461
# Epoch 87/100
# 51/51 [==============================] - 3s 55ms/step - loss: 1.6389e-06 - accuracy: 1.0000 - val_loss: 0.5476 - val_accuracy: 0.9412
# Epoch 88/100
# 51/51 [==============================] - 3s 55ms/step - loss: 8.3393e-07 - accuracy: 1.0000 - val_loss: 0.5485 - val_accuracy: 0.9412
# Epoch 89/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.1171e-06 - accuracy: 1.0000 - val_loss: 0.5501 - val_accuracy: 0.9412
# Epoch 90/100
# 51/51 [==============================] - 3s 55ms/step - loss: 8.2426e-07 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.9412
# Epoch 91/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.0334e-06 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.9412
# Epoch 92/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.7393e-06 - accuracy: 1.0000 - val_loss: 0.5563 - val_accuracy: 0.9436
# Epoch 93/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.0033e-06 - accuracy: 1.0000 - val_loss: 0.5561 - val_accuracy: 0.9412
# Epoch 94/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.7754e-06 - accuracy: 1.0000 - val_loss: 0.5582 - val_accuracy: 0.9412
# Epoch 95/100
# 51/51 [==============================] - 3s 52ms/step - loss: 7.3792e-07 - accuracy: 1.0000 - val_loss: 0.5583 - val_accuracy: 0.9461
# Epoch 96/100
# 51/51 [==============================] - 3s 52ms/step - loss: 5.8563e-07 - accuracy: 1.0000 - val_loss: 0.5600 - val_accuracy: 0.9461
# Epoch 97/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.0717e-06 - accuracy: 1.0000 - val_loss: 0.5632 - val_accuracy: 0.9461
# Epoch 98/100
# 51/51 [==============================] - 3s 53ms/step - loss: 5.4942e-07 - accuracy: 1.0000 - val_loss: 0.5640 - val_accuracy: 0.9461
# Epoch 99/100
# 51/51 [==============================] - 3s 53ms/step - loss: 6.6130e-07 - accuracy: 1.0000 - val_loss: 0.5647 - val_accuracy: 0.9461
# Epoch 100/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.1616e-06 - accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.9461

# %%
history = model.fit(X_train, Y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 51/51 [==============================] - 13s 76ms/step - loss: 0.8005 - accuracy: 0.6212 - val_loss: 0.6427 - val_accuracy: 0.7598
# Epoch 2/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.4100 - accuracy: 0.8422 - val_loss: 0.3631 - val_accuracy: 0.8480
# Epoch 3/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3157 - accuracy: 0.8883 - val_loss: 0.2285 - val_accuracy: 0.9118
# Epoch 4/100
# 51/51 [==============================] - 3s 54ms/step - loss: 0.2386 - accuracy: 0.9085 - val_loss: 0.2377 - val_accuracy: 0.9093
# Epoch 5/100
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1869 - accuracy: 0.9263 - val_loss: 0.2010 - val_accuracy: 0.9387
# Epoch 6/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.1580 - accuracy: 0.9411 - val_loss: 0.1957 - val_accuracy: 0.9461
# Epoch 7/100
# 51/51 [==============================] - 3s 51ms/step - loss: 0.1472 - accuracy: 0.9454 - val_loss: 0.1736 - val_accuracy: 0.9485
# Epoch 8/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.1072 - accuracy: 0.9540 - val_loss: 0.1861 - val_accuracy: 0.9289
# Epoch 9/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0676 - accuracy: 0.9767 - val_loss: 0.3227 - val_accuracy: 0.9240
# Epoch 10/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0754 - accuracy: 0.9699 - val_loss: 0.2528 - val_accuracy: 0.9436
# Epoch 11/100
# 51/51 [==============================] - 3s 54ms/step - loss: 0.0440 - accuracy: 0.9859 - val_loss: 0.3104 - val_accuracy: 0.9265
# Epoch 12/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0225 - accuracy: 0.9908 - val_loss: 0.3872 - val_accuracy: 0.9216
# Epoch 13/100
# 51/51 [==============================] - 3s 54ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.3242 - val_accuracy: 0.9436
# Epoch 14/100
# 51/51 [==============================] - 3s 51ms/step - loss: 0.0345 - accuracy: 0.9908 - val_loss: 0.2627 - val_accuracy: 0.9534
# Epoch 15/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0213 - accuracy: 0.9920 - val_loss: 0.3331 - val_accuracy: 0.9461
# Epoch 16/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0287 - accuracy: 0.9902 - val_loss: 0.3537 - val_accuracy: 0.9314
# Epoch 17/100
# 51/51 [==============================] - 3s 53ms/step - loss: 0.0315 - accuracy: 0.9859 - val_loss: 0.3177 - val_accuracy: 0.9387
# Epoch 18/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.3537 - val_accuracy: 0.9436
# Epoch 19/100
# 51/51 [==============================] - 3s 53ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.3355 - val_accuracy: 0.9436
# Epoch 20/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.4173 - val_accuracy: 0.9510
# Epoch 21/100
# 51/51 [==============================] - 3s 55ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.3301 - val_accuracy: 0.9485
# Epoch 22/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0213 - accuracy: 0.9926 - val_loss: 0.3730 - val_accuracy: 0.9314
# Epoch 23/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.3715 - val_accuracy: 0.9534
# Epoch 24/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.1224 - accuracy: 0.9564 - val_loss: 0.2269 - val_accuracy: 0.9338
# Epoch 25/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0282 - accuracy: 0.9853 - val_loss: 0.3333 - val_accuracy: 0.9167
# Epoch 26/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0265 - accuracy: 0.9896 - val_loss: 0.3728 - val_accuracy: 0.9265
# Epoch 27/100
# 51/51 [==============================] - 3s 52ms/step - loss: 0.0070 - accuracy: 0.9988 - val_loss: 0.3107 - val_accuracy: 0.9461
# Epoch 28/100
# 51/51 [==============================] - 3s 52ms/step - loss: 6.5810e-04 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9534
# Epoch 29/100
# 51/51 [==============================] - 3s 51ms/step - loss: 4.4267e-04 - accuracy: 1.0000 - val_loss: 0.3364 - val_accuracy: 0.9559
# Epoch 30/100
# 51/51 [==============================] - 3s 52ms/step - loss: 3.0224e-04 - accuracy: 1.0000 - val_loss: 0.3588 - val_accuracy: 0.9559
# Epoch 31/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.4775e-04 - accuracy: 1.0000 - val_loss: 0.3698 - val_accuracy: 0.9583
# Epoch 32/100
# 51/51 [==============================] - 3s 54ms/step - loss: 9.5914e-05 - accuracy: 1.0000 - val_loss: 0.3793 - val_accuracy: 0.9583
# Epoch 33/100
# 51/51 [==============================] - 3s 52ms/step - loss: 9.0366e-05 - accuracy: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.9583
# Epoch 34/100
# 51/51 [==============================] - 3s 53ms/step - loss: 7.8731e-05 - accuracy: 1.0000 - val_loss: 0.3959 - val_accuracy: 0.9583
# Epoch 35/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.8914e-04 - accuracy: 1.0000 - val_loss: 0.3913 - val_accuracy: 0.9559
# Epoch 36/100
# 51/51 [==============================] - 3s 53ms/step - loss: 9.8110e-05 - accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 0.9534
# Epoch 37/100
# 51/51 [==============================] - 3s 52ms/step - loss: 3.9013e-05 - accuracy: 1.0000 - val_loss: 0.3912 - val_accuracy: 0.9559
# Epoch 38/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.1739e-04 - accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 0.9583
# Epoch 39/100
# 51/51 [==============================] - 3s 52ms/step - loss: 4.9264e-05 - accuracy: 1.0000 - val_loss: 0.3958 - val_accuracy: 0.9583
# Epoch 40/100
# 51/51 [==============================] - 3s 53ms/step - loss: 4.4988e-05 - accuracy: 1.0000 - val_loss: 0.4088 - val_accuracy: 0.9559
# Epoch 41/100
# 51/51 [==============================] - 3s 54ms/step - loss: 8.7227e-06 - accuracy: 1.0000 - val_loss: 0.4173 - val_accuracy: 0.9559
# Epoch 42/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.4076e-05 - accuracy: 1.0000 - val_loss: 0.4249 - val_accuracy: 0.9583
# Epoch 43/100
# 51/51 [==============================] - 3s 55ms/step - loss: 1.9296e-05 - accuracy: 1.0000 - val_loss: 0.4474 - val_accuracy: 0.9559
# Epoch 44/100
# 51/51 [==============================] - 3s 55ms/step - loss: 1.1067e-05 - accuracy: 1.0000 - val_loss: 0.4420 - val_accuracy: 0.9583
# Epoch 45/100
# 51/51 [==============================] - 3s 53ms/step - loss: 7.8522e-06 - accuracy: 1.0000 - val_loss: 0.4429 - val_accuracy: 0.9583
# Epoch 46/100
# 51/51 [==============================] - 3s 54ms/step - loss: 5.8130e-06 - accuracy: 1.0000 - val_loss: 0.4538 - val_accuracy: 0.9608
# Epoch 47/100
# 51/51 [==============================] - 3s 53ms/step - loss: 5.8059e-06 - accuracy: 1.0000 - val_loss: 0.4515 - val_accuracy: 0.9583
# Epoch 48/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.2273e-05 - accuracy: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.9583
# Epoch 49/100
# 51/51 [==============================] - 3s 52ms/step - loss: 8.3088e-06 - accuracy: 1.0000 - val_loss: 0.4467 - val_accuracy: 0.9583
# Epoch 50/100
# 51/51 [==============================] - 3s 52ms/step - loss: 5.3007e-06 - accuracy: 1.0000 - val_loss: 0.4530 - val_accuracy: 0.9583
# Epoch 51/100
# 51/51 [==============================] - 3s 54ms/step - loss: 5.2660e-06 - accuracy: 1.0000 - val_loss: 0.4538 - val_accuracy: 0.9583
# Epoch 52/100
# 51/51 [==============================] - 3s 56ms/step - loss: 3.7620e-06 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.9583
# Epoch 53/100
# 51/51 [==============================] - 3s 53ms/step - loss: 7.7671e-06 - accuracy: 1.0000 - val_loss: 0.4640 - val_accuracy: 0.9559
# Epoch 54/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.7821e-06 - accuracy: 1.0000 - val_loss: 0.4670 - val_accuracy: 0.9559
# Epoch 55/100
# 51/51 [==============================] - 3s 53ms/step - loss: 3.1007e-06 - accuracy: 1.0000 - val_loss: 0.4737 - val_accuracy: 0.9583
# Epoch 56/100
# 51/51 [==============================] - 3s 52ms/step - loss: 3.1875e-06 - accuracy: 1.0000 - val_loss: 0.4765 - val_accuracy: 0.9608
# Epoch 57/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.7557e-06 - accuracy: 1.0000 - val_loss: 0.4777 - val_accuracy: 0.9583
# Epoch 58/100
# 51/51 [==============================] - 3s 53ms/step - loss: 3.5886e-06 - accuracy: 1.0000 - val_loss: 0.4827 - val_accuracy: 0.9608
# Epoch 59/100
# 51/51 [==============================] - 3s 54ms/step - loss: 2.0497e-06 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.9608
# Epoch 60/100
# 51/51 [==============================] - 3s 53ms/step - loss: 3.6119e-06 - accuracy: 1.0000 - val_loss: 0.4905 - val_accuracy: 0.9583
# Epoch 61/100
# 51/51 [==============================] - 3s 54ms/step - loss: 2.0842e-06 - accuracy: 1.0000 - val_loss: 0.4856 - val_accuracy: 0.9583
# Epoch 62/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.2628e-06 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.9583
# Epoch 63/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.9761e-06 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.9583
# Epoch 64/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.7519e-06 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.9608
# Epoch 65/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.7799e-06 - accuracy: 1.0000 - val_loss: 0.4947 - val_accuracy: 0.9608
# Epoch 66/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.9401e-06 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.9608
# Epoch 67/100
# 51/51 [==============================] - 3s 53ms/step - loss: 2.5486e-06 - accuracy: 1.0000 - val_loss: 0.5006 - val_accuracy: 0.9608
# Epoch 68/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.4275e-06 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.9608
# Epoch 69/100
# 51/51 [==============================] - 3s 53ms/step - loss: 8.6025e-07 - accuracy: 1.0000 - val_loss: 0.5039 - val_accuracy: 0.9608
# Epoch 70/100
# 51/51 [==============================] - 3s 54ms/step - loss: 1.8576e-06 - accuracy: 1.0000 - val_loss: 0.5083 - val_accuracy: 0.9608
# Epoch 71/100
# 51/51 [==============================] - 3s 55ms/step - loss: 3.0005e-06 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.9608
# Epoch 72/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.9641e-06 - accuracy: 1.0000 - val_loss: 0.5138 - val_accuracy: 0.9608
# Epoch 73/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.6442e-06 - accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.9583
# Epoch 74/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.0913e-06 - accuracy: 1.0000 - val_loss: 0.5122 - val_accuracy: 0.9608
# Epoch 75/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.2138e-06 - accuracy: 1.0000 - val_loss: 0.5178 - val_accuracy: 0.9608
# Epoch 76/100
# 51/51 [==============================] - 3s 55ms/step - loss: 1.5878e-06 - accuracy: 1.0000 - val_loss: 0.5192 - val_accuracy: 0.9608
# Epoch 77/100
# 51/51 [==============================] - 3s 55ms/step - loss: 1.6030e-06 - accuracy: 1.0000 - val_loss: 0.5217 - val_accuracy: 0.9608
# Epoch 78/100
# 51/51 [==============================] - 3s 53ms/step - loss: 4.3856e-07 - accuracy: 1.0000 - val_loss: 0.5217 - val_accuracy: 0.9608
# Epoch 79/100
# 51/51 [==============================] - 3s 54ms/step - loss: 2.7836e-06 - accuracy: 1.0000 - val_loss: 0.5313 - val_accuracy: 0.9608
# Epoch 80/100
# 51/51 [==============================] - 3s 54ms/step - loss: 8.7167e-07 - accuracy: 1.0000 - val_loss: 0.5332 - val_accuracy: 0.9583
# Epoch 81/100
# 51/51 [==============================] - 3s 53ms/step - loss: 9.0685e-07 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.9583
# Epoch 82/100
# 51/51 [==============================] - 3s 54ms/step - loss: 5.1641e-07 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.9583
# Epoch 83/100
# 51/51 [==============================] - 3s 53ms/step - loss: 9.5473e-07 - accuracy: 1.0000 - val_loss: 0.5289 - val_accuracy: 0.9608
# Epoch 84/100
# 51/51 [==============================] - 3s 54ms/step - loss: 1.9633e-06 - accuracy: 1.0000 - val_loss: 0.5249 - val_accuracy: 0.9583
# Epoch 85/100
# 51/51 [==============================] - 3s 51ms/step - loss: 1.1171e-06 - accuracy: 1.0000 - val_loss: 0.5265 - val_accuracy: 0.9608
# Epoch 86/100
# 51/51 [==============================] - 3s 54ms/step - loss: 1.3693e-06 - accuracy: 1.0000 - val_loss: 0.5329 - val_accuracy: 0.9608
# Epoch 87/100
# 51/51 [==============================] - 3s 53ms/step - loss: 6.2727e-07 - accuracy: 1.0000 - val_loss: 0.5392 - val_accuracy: 0.9608
# Epoch 88/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.1288e-06 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.9608
# Epoch 89/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.2786e-06 - accuracy: 1.0000 - val_loss: 0.5317 - val_accuracy: 0.9608
# Epoch 90/100
# 51/51 [==============================] - 3s 56ms/step - loss: 4.8019e-07 - accuracy: 1.0000 - val_loss: 0.5335 - val_accuracy: 0.9608
# Epoch 91/100
# 51/51 [==============================] - 3s 53ms/step - loss: 5.0001e-07 - accuracy: 1.0000 - val_loss: 0.5318 - val_accuracy: 0.9608
# Epoch 92/100
# 51/51 [==============================] - 3s 55ms/step - loss: 8.8761e-06 - accuracy: 1.0000 - val_loss: 0.5499 - val_accuracy: 0.9534
# Epoch 93/100
# 51/51 [==============================] - 3s 55ms/step - loss: 1.0175e-05 - accuracy: 1.0000 - val_loss: 0.4804 - val_accuracy: 0.9608
# Epoch 94/100
# 51/51 [==============================] - 3s 54ms/step - loss: 1.6468e-06 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.9583
# Epoch 95/100
# 51/51 [==============================] - 3s 55ms/step - loss: 2.5066e-06 - accuracy: 1.0000 - val_loss: 0.4985 - val_accuracy: 0.9583
# Epoch 96/100
# 51/51 [==============================] - 3s 52ms/step - loss: 2.0638e-06 - accuracy: 1.0000 - val_loss: 0.5048 - val_accuracy: 0.9583
# Epoch 97/100
# 51/51 [==============================] - 3s 53ms/step - loss: 1.1648e-06 - accuracy: 1.0000 - val_loss: 0.5124 - val_accuracy: 0.9583
# Epoch 98/100
# 51/51 [==============================] - 3s 52ms/step - loss: 1.6307e-06 - accuracy: 1.0000 - val_loss: 0.5197 - val_accuracy: 0.9583
# Epoch 99/100
# 51/51 [==============================] - 3s 53ms/step - loss: 3.3693e-05 - accuracy: 1.0000 - val_loss: 0.5421 - val_accuracy: 0.9461
# Epoch 100/100
# 51/51 [==============================] - 3s 53ms/step - loss: 0.2041 - accuracy: 0.9312 - val_loss: 0.5033 - val_accuracy: 0.8382

# %%
#Evaluasi model menggunakan grafik loss dan accuracy

plt.style.use("ggplot")

plt.plot(np.arange(0, 100), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), history.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.show()

plt.plot(np.arange(0, 100), history.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, 100), history.history["val_accuracy"], label="val_accuracy")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# plot training and validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# plot training and validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
# find the accuracy on train and test set
train_loss, train_acc = model.evaluate(X_train, Y_train)
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Accuracy on train set is %f" %(train_acc * 100)  + "%")
print("Accuracy on validation set is %f" %(test_acc * 100)  + "%")
# Out:
# 64/64 [==============================] - 2s 25ms/step - loss: 0.3694 - accuracy: 0.8601
# 28/28 [==============================] - 1s 25ms/step - loss: 0.5570 - accuracy: 0.8076
# Accuracy on train set is 86.008835%
# Accuracy on validation set is 80.756015%

# %%
#save model.h5
model.save('model_cnn_ml2.h5')

# %%
Y_pred = model.predict(X_test)
Y_pred = np.argmax(Y_pred, axis = 1)
Y_test = np.argmax(Y_test, axis = 1)

# get the correctly and incorrectly labelled images
correct = np.nonzero(Y_pred == Y_test)[0]
incorrect = np.nonzero(Y_pred != Y_test)[0]

print("correct shape:" + str(correct.shape))
print("incorrect shape:" + str(incorrect.shape))

# Classification Report
print(classification_report(Y_test, Y_pred))
# Out:
# correct shape:(828,)
# incorrect shape:(45,)
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.86        59
#            1       0.96      0.94      0.95       411
#            2       0.96      0.97      0.96       403
#
#     accuracy                           0.95       873
#    macro avg       0.91      0.94      0.92       873
# weighted avg       0.95      0.95      0.95       873

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(Y_test, Y_pred), annot=True, fmt=".0f", ax=ax)
plt.xlabel("y_head")
plt.ylabel("y_true")
plt.show()

# %%
# !pip install pyyaml h5py
model_json = model.to_json()
with open("model_cnn6_tkc.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_cnn6_tkc.hdf5")
print("Saved model to disk")
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Saved model to disk
